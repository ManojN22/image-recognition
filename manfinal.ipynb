# %%
import cv2
import numpy as np
import pandas as pd
from matplotlib import pyplot as f
import tkinter as m
import os
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray
import warnings
warnings.simplefilter('ignore')
from PIL import Image

# %%
def imreg(img):
    gray=[None]*pic
    for i in range(pic) :
        gray[i]=rgb2gray(img[i])
        gray[i]=resize(gray[i],(512,512))
        gray[i]=np.ndarray.flatten(gray[i]).reshape(262144,1)
    return df(gray)

def df(pf):
    pf=np.dstack(pf)
    pf=np.rollaxis(pf,axis=2,start=0)
    pf=pf.reshape(pic,262144)
    pf=pd.DataFrame(pf)
    return pf

# %%
li=os.listdir("C:/Users/NANDA KUMAR/Desktop/test/test case/")
lm=os.listdir("C:/Users/NANDA KUMAR/Downloads/russia flag/")
pic=0

# %%
flag=[None]*200
j=0
o=''
l=[None]
k="C:/Users/NANDA KUMAR/Downloads/russia flag/"
for y in lm:
    try:
        o=k+y
        l=Image.open(o)
        
        if l is not None:
            l.save('C:/Users/NANDA KUMAR/Desktop/test/test case/russia flag/{}.png'.format(j)) 
            j+=1
    except IOError: 
        pass

# %%
flag=imreg(flag)

# %%
flag=[None]*200
j=0
l=[None]*5
m=0
o=''
for i in li :
    print(i)
    h=os.listdir("C:/Users/NANDA KUMAR/Desktop/test/test case/"+i)
    k="C:/Users/NANDA KUMAR/Desktop/test/test case/"+i+"/"
    for y in h:
        o=k+y
        flag[j]=imread(o)
        j+=1
    l[m]=j
    m+=1
# Out:
# american flag
# french flag
# germany flag
# italian flag
# russia flag

# %%
f.imshow(flag[1])

# %%
pic=j
pf=imreg(flag)
pf=pd.DataFrame(pf)
pf
# Out:
#        0         1         2         3         4         5         6       \
# 0    0.138820  0.138820  0.138820  0.138820  0.138820  0.138820  0.138820
# 1    0.529428  0.228322  0.228365  0.229497  0.224089  0.221552  0.220574
# 2    0.484343  0.484166  0.482371  0.480001  0.478614  0.476707  0.479265
# 3    0.100339  0.100339  0.100303  0.100299  0.099480  0.099115  0.100902
# 4    1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 152  0.979485  0.814268  0.778280  0.790034  0.793383  0.788267  0.793389
# 153  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 154  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 155  0.163656  0.163656  0.163656  0.163656  0.163656  0.163656  0.163656
# 156  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
#
#        7         8         9       ...    262134    262135    262136  \
# ...

# %%
pf["label"]='american'

# %%
pf[l[0]:l[1]]["label"]='french'

# %%
pf[l[1]:l[2]]["label"]='germany'

# %%
pf[l[2]:l[3]]["label"]='italian'
pf[l[3]:l[4]]["label"]='russia'

# %%
pf
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.138820  0.138820  0.138820  0.138820  0.138820  0.138820  0.138820
# 1    0.529428  0.228322  0.228365  0.229497  0.224089  0.221552  0.220574
# 2    0.484343  0.484166  0.482371  0.480001  0.478614  0.476707  0.479265
# 3    0.100339  0.100339  0.100303  0.100299  0.099480  0.099115  0.100902
# 4    1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 152  0.979485  0.814268  0.778280  0.790034  0.793383  0.788267  0.793389
# 153  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 154  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 155  0.163656  0.163656  0.163656  0.163656  0.163656  0.163656  0.163656
# 156  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
#
#             7         8         9  ...    262135    262136    262137  \
# ...

# %%
pf.to_csv("C:/Users/NANDA KUMAR/Desktop/test/ans.csv")

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.utils import shuffle

# %%
pf=shuffle(pf).reset_index()
pf=pf.drop(['index'],axis=1)
pf
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.302439  0.318243  0.279015  0.233480  0.337113  0.286266  0.273512
# 1    0.006526  0.006382  0.003024  0.000000  0.000000  0.000000  0.000000
# 2    0.888018  0.901574  0.911867  0.915954  0.921279  0.922052  0.920808
# 3    1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 4    0.539600  0.545918  0.547500  0.546920  0.550710  0.556888  0.556817
# ..        ...       ...       ...       ...       ...       ...       ...
# 152  0.940098  0.940098  0.940098  0.939995  0.938233  0.938126  0.938126
# 153  0.727583  0.687145  0.680560  0.727446  0.720654  0.669031  0.711534
# 154  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 155  0.027400  0.064683  0.075574  0.064168  0.074602  0.084659  0.074800
# 156  0.053084  0.049410  0.147702  0.121183  0.114843  0.157944  0.117073
#
#             7         8         9  ...    262135    262136    262137  \
# ...

# %%
x=pf.values[:,:-1]
y=pf.values[:,-1]

# %%
x
# Out:
# array([[0.3024391294070582, 0.31824320863033384, 0.27901527367072004,
#         ..., 0.030613524948391257, 0.04132401975489921,
#         0.052917296634466614],
#        [0.006525735294117647, 0.006382347555721324, 0.003023888083065075,
#         ..., 0.38374322162404273, 0.3871983435103468, 0.4090438700507632],
#        [0.8880176966215111, 0.9015742776862197, 0.9118667986497215, ...,
#         0.19840487538821389, 0.20042486730534534, 0.19334597476412413],
#        ...,
#        [1.0, 1.0, 1.0, ..., 0.0748443137254902, 0.0748443137254902,
#         0.0748443137254902],
#        [0.027399717164884155, 0.06468324662153128, 0.07557418589275267,
#         ..., 0.22815087112127208, 0.234961712401147, 0.22422469362745368],
#        [0.053083746697627734, 0.049409646092304096, 0.14770150823349773,
#         ..., 0.12614658772125334, 0.14594141376163283,
#         0.12338738860225625]], dtype=object)

# %%
test = svm.SVC()

# %%
test.fit(x,y)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
xi= test.predict(x)

# %%
pos=0
neg=0
for i in range(27):
    if x[i]==yte[i]:
        pos+=1
    else:
        neg+=1

# %%
xi,y
# Out:
# (array(['russia', 'germany', 'russia', 'italian', 'italian', 'germany',
#         'germany', 'russia', 'italian', 'french', 'american', 'american',
#         'italian', 'french', 'italian', 'italian', 'russia', 'germany',
#         'italian', 'germany', 'germany', 'germany', 'italian', 'american',
#         'italian', 'germany', 'italian', 'american', 'italian', 'american',
#         'italian', 'american', 'italian', 'french', 'american', 'russia',
#         'french', 'italian', 'american', 'french', 'germany', 'american',
#         'french', 'italian', 'french', 'italian', 'french', 'russia',
#         'russia', 'russia', 'russia', 'germany', 'american', 'french',
#         'russia', 'italian', 'germany', 'american', 'french', 'russia',
#         'american', 'russia', 'french', 'germany', 'french', 'italian',
#         'italian', 'french', 'germany', 'french', 'american', 'american',
#         'germany', 'italian', 'germany', 'american', 'germany', 'american',
# ...

# %%
cap = cv2.VideoCapture(0)
pic=1
k=0
pre=''
while(True):
    
    """ret, frame = cap.read()"""
    f=imreg(flag[k])
    if pre!=test.predict(f):
        clear_output()
        print(test.predict(f))
    cv2.imshow('frame',flag[k])
    pre=test.predict(f)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    if cv2.waitKey(1) & 0xFF == ord('d'):
        k+=1

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# ['american']

# %%
f=imreg(frame)

# %%
ans=test.predict(f)

# %%
ans
# Out:
# array(['french'], dtype=object)

# %%
from IPython.display import clear_output

# %%
print("man")
clear_output()
# Out:
# m
